# %% [markdown]
# データ分析の手順:PPDACサイクル
#
# ①Problem    「問題の把握」
# ②Plan       「調査の計画」
# ③Data       「データの収集」
# ④Analysis   「データの分析」
# ⑤Conclusion 「結論を考える」

# %%
# list1.1.py
print("Hello")
# Out:
# Hello

# %%
# list1.2.py
import matplotlib.pyplot as plt

plt.plot([0, 2, 1, 3])
plt.show()
