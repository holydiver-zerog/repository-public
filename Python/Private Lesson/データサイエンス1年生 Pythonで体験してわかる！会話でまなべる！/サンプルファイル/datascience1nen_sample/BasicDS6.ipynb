# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# prompt: icecream_sales.csvを読み込んで

import pandas as pd

# icecream_sales.csvを読み込む
df = pd.read_csv('icecream_sales.csv')

# データフレームを表示
print(df)
# Out:
#               日付  曜日    気温    年齢  性別       味   値段
# 0     2024-01-01   0   6.8  33.0  女性  ストロベリー  320
# 1     2024-01-02   1   8.3  29.0  女性  ストロベリー  320
# 2     2024-01-02   1   8.3  34.0  男性      抹茶  350
# 3     2024-01-03   2   7.4  17.0  女性  ストロベリー  320
# 4     2024-01-04   3  10.1  67.0  女性     バニラ  300
# ...          ...  ..   ...   ...  ..     ...  ...
# 3039  2024-12-29   6   7.3  66.0  女性   キャラメル  330
# 3040  2024-12-29   6   7.3  35.0  男性      抹茶  350
# 3041  2024-12-30   0   9.0  40.0  女性  ストロベリー  320
# 3042  2024-12-30   0   9.0  59.0  男性     バニラ  300
# 3043  2024-12-31   1   7.8  22.0  女性     バニラ  300
#
# [3044 rows x 7 columns]

# %%
df.head()
# Out:
#            日付  曜日    気温    年齢  性別       味   値段
# 0  2024-01-01   0   6.8  33.0  女性  ストロベリー  320
# 1  2024-01-02   1   8.3  29.0  女性  ストロベリー  320
# 2  2024-01-02   1   8.3  34.0  男性      抹茶  350
# 3  2024-01-03   2   7.4  17.0  女性  ストロベリー  320
# 4  2024-01-04   3  10.1  67.0  女性     バニラ  300

# %%
# prompt: DataFrame df を使用: 「男性と女性で味に好みの違いがあるか」という仮説を検証して

# ライブラリのインポート
import pandas as pd
from scipy import stats

# 「男性」と「女性」でグループ化し、味の好みを比較
male_preferences = df[df['性別'] == '男性']['味'].value_counts()
female_preferences = df[df['性別'] == '女性']['味'].value_counts()

# chi2検定で独立性の検定を行う
contingency_table = pd.crosstab(df['性別'], df['味'])
chi2, p, _, _ = stats.chi2_contingency(contingency_table)

# 結果を表示
print("カイ二乗統計量:", chi2)
print("p値:", p)

# p値が0.05より小さい場合、帰無仮説（男性と女性の味の好みは独立である）を棄却
if p < 0.05:
    print("男性と女性で味の好みには有意な差があると考えられます。")
else:
    print("男性と女性で味の好みには有意な差があるとは言えません。")

# 男性と女性の味の好みを比較する棒グラフを作成
# （Altairなどのライブラリを利用）
# Out:
# カイ二乗統計量: 8.295632958284374
# p値: 0.14067777305071077
# 男性と女性で味の好みには有意な差があるとは言えません。

# %%
df.head()
# Out:
#            日付  曜日    気温    年齢  性別       味   値段
# 0  2024-01-01   0   6.8  33.0  女性  ストロベリー  320
# 1  2024-01-02   1   8.3  29.0  女性  ストロベリー  320
# 2  2024-01-02   1   8.3  34.0  男性      抹茶  350
# 3  2024-01-03   2   7.4  17.0  女性  ストロベリー  320
# 4  2024-01-04   3  10.1  67.0  女性     バニラ  300

# %%
# @title 曜日

from matplotlib import pyplot as plt
df['曜日'].plot(kind='hist', bins=20, title='曜日')
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 26332 (\N{CJK UNIFIED IDEOGRAPH-66DC}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26332 (\N{CJK UNIFIED IDEOGRAPH-66DC}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
